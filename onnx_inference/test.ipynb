# %%
# !pip install matplotlib
# Out:
# /bin/bash: /home/main/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 13.8 MB/s eta 0:00:0000:0100:01
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.0.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 kB 24.4 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.39.4-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.1 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading kiwisolver-1.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 20.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.20 in /home/main/anaconda3/envs/yolov7/lib/python3.11/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /home/main/anaconda3/envs/yolov7/lib/python3.11/site-packages (from matplotlib) (23.1)
# Collecting pillow>=6.2.0 (from matplotlib)
#   Downloading Pillow-9.5.0-cp311-cp311-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 25.2 MB/s eta 0:00:00a 0:00:01
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/main/anaconda3/envs/yolov7/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/main/anaconda3/envs/yolov7/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.4 kiwisolver-1.4.4 matplotlib-3.7.1 pillow-9.5.0 pyparsing-3.0.9

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread('../onnx_inference/img.png')
height, width, _ = img.shape
print(height,width)
# Out:
# 640 640

# %%
with open('../runs/detect/exp7/labels/img.txt', 'r') as file:
    list = [[float(num) for num in line.split()] for line in file]

# %%
list
# Out:
# [[0.0,
#   0.599304,
#   0.519385,
#   0.199707,
#   0.290039,
#   306.043,
#   222.596,
#   0.508507,
#   306.251,
#   43.6012,
#   0.398086,
#   304.165,
#   218.84,
#   0.370582,
#   306.46,
#   48.8167,
#   0.340634,
#   303.957,
#   218.84,
#   0.271978,
#   336.501,
#   227.602,
#   0.562699,
#   308.338,
#   231.149,
#   0.54477,
#   354.234,
#   251.385,
#   0.519101,
#   297.281,
#   245.961,
#   0.485689,
#   352.356,
#   266.405,
#   0.518693,
#   286.224,
#   247.213,
#   0.489764,
#   342.551,
#   273.916,
#   0.550475,
#   322.941,
#   274.959,
#   0.545178,
#   347.766,
#   306.251,
#   0.45024,
#   310.424,
#   305.626,
#   0.445351,
#   360.284,
#   339.839,
#   0.355507,
#   311.884,
#   339.422,
#   0.352654,
#   354.025,
#   348.184,
#   0.121219,
#   360.284,
#   347.975,
#   0.120506,
#   361.744,
#   342.551,
#   0.125497,
#   301.245,
#   345.889,
#   0.120913,
#   299.367,
#   344.22,
#   0.119691,
#   317.1,
#   341.925,
#   0.12458,
#   303.748,
#   219.675,
#   0.321688,
#   304.791,
#   221.344,
#   0.325762,
#   305.834,
#   223.013,
#   0.330244,
#   307.086,
#   224.473,
#   0.335134,
#   308.338,
#   225.933,
#   0.339208,
#   309.798,
#   227.185,
#   0.343283,
#   311.258,
#   228.437,
#   0.347969,
#   312.927,
#   228.854,
#   0.352247,
#   314.805,
#   227.811,
#   0.355099,
#   316.057,
#   226.351,
#   0.356118,
#   317.1,
#   224.89,
#   0.356321,
#   317.934,
#   223.013,
#   0.354692,
#   318.143,
#   220.927,
#   0.351636,
#   177.128,
#   0.138433,
#   115.64,
#   178.176,
#   0.139797,
#   116.688,
#   179.05,
#   0.140138,
#   117.911,
#   179.574,
#   0.139456,
#   119.221,
#   179.574,
#   0.138091,
#   120.007,
#   178.351,
#   0.136215,
#   120.531,
#   177.041,
#   0.133827,
#   120.88,
#   175.731,
#   0.131097,
#   120.968,
#   174.508,
#   0.128283,
#   120.968,
#   173.198,
#   0.125127,
#   120.968,
#   171.888,
#   0.122397,
#   120.88,
#   170.49,
#   0.119753,
#   117.387,
#   169.617,
#   0.122824,
#   117.911,
#   169.355,
#   0.121544,
#   118.522,
#   169.267,
#   0.120691,
#   119.134,
#   169.267,
#   0.120265,
#   119.658,
#   169.442,
#   0.119924,
#   120.094,
#   169.529,
#   0.118559,
#   120.182,
#   169.529,
#   0.118218,
#   120.356,
#   169.442,
#   0.117791,
#   120.444,
#   169.529,
#   0.117791,
#   120.618,
#   169.529,
#   0.118388,
#   119.92,
#   170.84,
#   0.121203,
#   120.182,
#   171.713,
#   0.122909,
#   120.618,
#   172.499,
#   0.12453,
#   120.968,
#   173.46,
#   0.126577,
#   119.308,
#   174.159,
#   0.12888,
#   119.658,
#   174.333,
#   0.128794,
#   120.007,
#   174.333,
#   0.128453,
#   120.531,
#   174.333,
#   0.127856,
#   121.055,
#   174.159,
#   0.127259,
#   117.823,
#   170.84,
#   0.124018,
#   118.26,
#   170.665,
#   0.122824,
#   118.697,
#   170.665,
#   0.122056,
#   118.959,
#   170.84,
#   0.122141,
#   118.609,
#   171.014,
#   0.123165,
#   118.26,
#   171.014,
#   0.123762,
#   120.094,
#   170.752,
#   0.120606,
#   120.182,
#   170.752,
#   0.119924,
#   120.356,
#   170.752,
#   0.119753,
#   120.531,
#   170.84,
#   0.120094,
#   120.356,
#   170.84,
#   0.120521,
#   120.182,
#   170.84,
#   0.120691,
#   118.435,
#   176.255,
#   0.1334,
#   119.134,
#   175.905,
#   0.132035,
#   119.832,
#   175.731,
#   0.130841,
#   120.007,
#   175.731,
#   0.130756,
#   120.182,
#   175.818,
#   0.130585,
#   120.182,
#   176.08,
#   0.130415,
#   120.094,
#   176.429,
#   0.130756,
#   120.007,
#   176.604,
#   0.132206,
#   120.007,
#   176.953,
#   0.13323,
#   119.658,
#   177.128,
#   0.134338,
#   119.308,
#   177.041,
#   0.134509,
#   118.872,
#   176.779,
#   0.134083,
#   118.609,
#   176.342,
#   0.13323,
#   119.134,
#   176.255,
#   0.132291,
#   119.832,
#   176.255,
#   0.131694,
#   119.92,
#   176.255,
#   0.131183,
#   120.094,
#   176.429,
#   0.130841,
#   119.832,
#   176.429,
#   0.132035,
#   119.658,
#   176.429,
#   0.132803,
#   119.134,
#   176.429,
#   0.13323,
#   123.675,
#   222.72,
#   0.204877,
#   120.706,
#   224.118,
#   0.204024,
#   122.977,
#   224.467,
#   0.203171,
#   121.404,
#   226.039,
#   0.203,
#   122.453,
#   227.437,
#   0.202318,
#   123.85,
#   225.69,
#   0.201124,
#   124.112,
#   227.087,
#   0.200953,
#   123.85,
#   229.184,
#   0.200612,
#   123.85,
#   227.961,
#   0.200953,
#   123.151,
#   225.69,
#   0.201636,
#   122.103,
#   227.437,
#   0.200953,
#   123.588,
#   228.135,
#   0.202318,
#   122.453,
#   228.31,
#   0.202318,
#   123.413,
#   227.087,
#   0.202318,
#   123.501,
#   228.485,
#   0.201977,
#   123.675,
#   228.834,
#   0.202489,
#   123.85,
#   228.485,
#   0.203,
#   123.85,
#   227.262,
#   0.202489,
#   123.675,
#   229.009,
#   0.202659,
#   122.977,
#   229.184,
#   0.203171,
#   123.326,
#   228.834,
#   0.203341,
#   116.688,
#   224.467,
#   0.223983,
#   116.863,
#   224.642,
#   0.222447,
#   118.26,
#   225.166,
#   0.221253,
#   119.134,
#   226.389,
#   0.219889,
#   170.875,
#   326.75,
#   0.312256,
#   167.375,
#   324.0,
#   0.313477,
#   168.375,
#   326.0,
#   0.310791,
#   168.625,
#   327.75,
#   0.310547,
#   168.875,
#   328.25,
#   0.30957,
#   166.5,
#   325.5,
#   0.313477,
#   167.125,
#   328.0,
#   0.311279,
#   167.375,
#   329.25,
#   0.310791,
#   168.25,
#   329.5,
#   0.310791,
#   166.0,
#   326.25,
#   0.314697,
#   165.625,
#   329.0,
#   0.3125,
#   166.875,
#   329.75,
#   0.312744,
#   167.0,
#   330.0,
#   0.312988,
#   165.375,
#   327.5,
#   0.314941,
#   166.375,
#   329.0,
#   0.313477,
#   166.0,
#   329.75,
#   0.313477,
#   166.75,
#   330.5,
#   0.313965]]

# %%
for data in list:
    box = data[1:5]
    keypoints=data[5:]
    # Rescale the box coordinates to the image dimensions
    box = [int(coord * (width if i % 2 == 0 else height)) for i, coord in enumerate(box)]
    x, y, w, h = box

    # Draw the bounding box
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)  # green box

    # Draw the keypoints
    for i in range(0, len(keypoints), 3):
        x, y = map(int, keypoints[i:i+2])
        cv2.circle(img, (x, y), 5, (0, 0, 255), -1) 
    
    # Show the image with matplotlib
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convert the image from BGR to RGB format
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[18], line 14
#      12 for i in range(0, len(keypoints), 3):
#      13     x, y = keypoints[i:i+2]
# ---> 14     cv2.circle(img, (x, y), 5, (0, 0, 255), -1)
#      16 # Show the image with matplotlib
#      17 plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convert the image from BGR to RGB format
#
# error: OpenCV(4.7.0) :-1: error: (-5:Bad argument) in function 'circle'
# > Overload resolution failed:
# >  - Can't parse 'center'. Sequence item with index 0 has a wrong type
# >  - Can't parse 'center'. Sequence item with index 0 has a wrong type
